# %% [markdown]
# # Dados da JFRN

# %% [markdown]
# Carregando ferramentas do google para abrir o arquivo dos processos

# %%
# %unload_ext google.colab.data_table

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Carregando o arquivo dos processos para o PANDAS (a tabela)
# Isso demora um pouco a primeira vez porque são muitos dados

# %%
import pandas as pd

df = pd.read_csv('/content/drive/My Drive/metadados2017a.csv.gz',compression = 'gzip',  encoding = "ISO-8859-1")
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (18,23,24) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pd.set_option('display.max_rows', 100)
pagina = 1
limiar = (pagina-1)*100
limite = (pagina)*100
df[limiar:limite]
# Out:
#           NÃºmero do processo  CÃ³digo da classe processual  \
# 0   0800587-34.2017.4.05.8401                           156
# 1   0800147-38.2017.4.05.8401                         12078
# 2   0800147-38.2017.4.05.8401                         12078
# 3   0800147-38.2017.4.05.8401                         12078
# 4   0800147-38.2017.4.05.8401                         12078
# 5   0800147-38.2017.4.05.8401                         12078
# 6   0800147-38.2017.4.05.8401                         12078
# 7   0800147-38.2017.4.05.8401                         12078
# 8   0800147-38.2017.4.05.8401                         12078
# 9   0800147-38.2017.4.05.8401                         12078
# 10  0800147-38.2017.4.05.8401                         12078
# 11  0800147-38.2017.4.05.8401                         12078
# 12  0800147-38.2017.4.05.8401                         12078
# 13  0800147-38.2017.4.05.8401                         12078
# 14  0800147-38.2017.4.05.8401                         12078
# ...

# %%
import IPython
movimentacao = 0
movimentacaoLimite = movimentacao+1
html = df[movimentacao:movimentacaoLimite]['ConteÃºdo do Documento'].values[0]
IPython.display.HTML(html)
# Out:
# <div><span style="font-size: medium;"><strong>PROCESSO N&ordm;:</strong> 0800587-34.2017.4.05.8401<strong> - APELA&Ccedil;&Atilde;O / REMESSA NECESS&Aacute;RIA</strong><br /><strong>APELANTE: </strong>UNI&Atilde;O FEDERAL  <br /><strong>APELADO: </strong>JOS&Eacute; LUIZ BALLIANA  e outros <br /><strong>ADVOGADO: </strong>Angelo Eug&ecirc;nio Couto Da Silveira  <br /><strong>RELATOR(A): </strong>Desembargador(a) Federal Paulo Roberto de Oliveira Lima - 2&ordf; Turma<br /><strong>JUIZ PROLATOR DA SENTEN&Ccedil;A (1&deg; GRAU): </strong>Juiz(a) Federal Orlan Donato Rocha</span></div>
# <p align="center"><span style="font-size: medium;"><strong>VOTO</strong></span></p>
# <p style="text-align: justify;"><span style="font-size: medium;"><strong>O SR. DESEMBARGADOR FEDERAL PAULO ROBERTO DE OLIVEIRA LIMA (RELATOR):</strong></span></p>
# ...

# %% [markdown]
# Agora vamos procurar todas as Descrições do Assunto, uma única vez cada uma

# %%
df['DescriÃ§Ã£o do Assunto'].unique()
# Out:
# array(['Correção Monetária de Diferenças Pagas em Atraso',
#        'Correção Monetária', 'Conselhos Regionais e Afins (Anuidade)',
#        'Anulação de Débito Fiscal', 'Exercício Profissional',
#        'Questões Funcionais', 'Multas e demais Sanções', 'Liminar ',
#        'Concessão', 'Não Cumulatividade',
#        'Constrição / Penhora / Avaliação / Indisponibilidade de Bens',
#        'Vícios de Construção',
#        'Cálculo do Benefício de acordo com a Sistemática anterior à Lei 9.876/99',
#        'Abono da Lei 8.178/91', 'Exclusão - ICMS',
#        'Fornecimento de Medicamentos',
#        'Efeito Suspensivo / Impugnação / Embargos à Execução',
#        '1/3 de férias',
#        'Arquivamento Administrativo - Crédito de Pequeno Valor',
#        'Complementação de Benefício/Ferroviário', 'Posse e Exercício',
#        'Acumulação de Cargos',
#        'Unidade de terapia intensiva (UTI) ou unidade de cuidados intensivos (UCI)',
# ...

# %% [markdown]
# Agora vamos procurar quantos processos tem em cada descrição de assunto

# %%
processosPorAssunto = df.groupby('DescriÃ§Ã£o do Assunto')['NÃºmero do processo'].nunique()
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(processosPorAssunto)
# Out:
# DescriÃ§Ã£o do Assunto
# 1/3 de férias                                                                                        11
# ASSISTÊNCIA SOCIAL                                                                                    2
# Abatimento proporcional do preço                                                                      1
# Abono da Lei 8.178/91                                                                                 4
# Abono de Permanência                                                                                  1
# Abono de Permanência em Serviço (Art. 87)                                                             2
# Abuso de Poder                                                                                       14
# Acidente de Trânsito                                                                                  5
# Acumulação de Cargos                                                                                  5
# ...
